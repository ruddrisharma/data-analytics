# %%
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.distplot(tips["total_bill"])

# %%
sns.distplot(tips["total_bill"],kde=False)

# %%
sns.distplot(tips["size"],kde=False)

# %%
#bivariable analysis ----- two variables.
{"scatter","reg","resid","kde","hex"}
# Out:
# {'hex', 'kde', 'reg', 'resid', 'scatter'}

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.jointplot(["total_bill"],["tip"],data=tips)

# %%
sns.jointplot(["total_bill"],["size"],data=tips)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import matplotlib.pyplot as plt

# %%
sns.jointplot("total_bill","tip",data=tips,kind="hex",color="k")
plt.savefig("tip.png")

# %%
sns.pairplot(tips)

# %%
#ploting of catogorical data using seaborn lib
1.barplot
2.countplot
3.voilinplot
4.stripplot
5.swarm plot

# %%
import numpy as np

# %%
sns.barplot(x="sex",y="total_bill",data=tips,)

# %%
sns.barplot(x="sex",y="total_bill",data=tips,)

# %%
#by defalut estimator is mean ,although we can change by using estimator parameter.

# %%
#countplot----kitne females aaye n kitne males aaye

# %%
sns.countplot("sex",data=tips)

# %%
sns.countplot("smoker",data=tips,palette="vlag",hue="sex")

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette="rainbow",hue="sex")

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette="rainbow")

# %%
sns.boxplot(data=tips,orient="h")

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette="rainbow",hue="sex")

# %%
sns.violinplot(x="day",y="total_bill",data=tips,palette="icefire")

# %%
sns.countplot("time",data=tips,palette="winter",hue="sex")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot("day",data=tips,palette="brg",hue="sex")
